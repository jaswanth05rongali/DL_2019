# %%
from __future__ import print_function
import numpy as np
import mxnet as mx
from mxnet import nd, autograd, gluon
import dataloader
from sklearn.model_selection import train_test_split

#Set Contexts
ctx = mx.gpu() if mx.test_utils.list_gpus() else mx.cpu()
data_ctx = ctx
model_ctx = ctx


#load the data
num_inputs = 784
batch_size = 64
num_instances = 60000
data = dataloader.DataLoader()
train_data,train_labels = data.load_data()
test_data,test_labels = data.load_data(mode = 'test')
X_train, X_val, y_train, y_val = train_test_split(train_data, train_labels, test_size=0.30, random_state=42)

def transform(data, label):
    return data.astype(np.float32)/255, label.astype(np.float32)

train_data = []
for index,data in enumerate(X_train):
    temp = y_train[index]
    train_data.append((data,temp))
    
val_data = []
for index,data in enumerate(X_val):
    temp = y_val[index]
    val_data.append((data,temp))
    
test_data = []
for index,data in enumerate(test_data):
    temp = labels_test[index]
    test_data.append((data,temp))

train_data = gluon.data.DataLoader(train_data,batch_size, shuffle=True)
test_data = gluon.data.DataLoader(test_data,batch_size, shuffle=False)
val_data = gluon.data.DataLoader(val_data,batch_size,shuffle=False)

#Defining the model using nn.Sequential
num_outputs = 10
network = gluon.nn.Sequential()
with network.name_scope():
    network.add(gluon.nn.Dense(512, activation="relu"))
    network.add(gluon.nn.Dense(128, activation="relu"))
    network.add(gluon.nn.Dense(64, activation="relu"))
    network.add(gluon.nn.Dense(32, activation="relu"))
    network.add(gluon.nn.Dense(16, activation="relu"))
    network.add(gluon.nn.Dense(num_outputs,activation="softmax"))

#Parameter Initialization
network.collect_params().initialize()

#loss definition
softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()

#optimizer
lr = 0.001
param_update = gluon.Trainer(network.collect_params(), 'adam', {'learning_rate': lr})

#Accuracy Evaluation
def accuracy(data_iter,network):
    acc = mx.metric.Accuracy()
    for e,(data, label) in enumerate(data_iter):
        data = data.as_in_context(model_ctx)
        label = label.as_in_context(model_ctx)
        output = network(data)
        predictions = nd.argmax(output, axis=1)
        acc.update(preds=predictions, labels=label)
    return acc.get()[1]

#Training the Model
epochs = 2

for i in range(epochs):
    cumulative_loss = 0
    for e,(data,label) in enumerate(train_data):
        data , label = transform(data,label)
        data = data.as_in_context(model_ctx)
        label = label.as_in_context(model_ctx)
        with autograd.record():
            output = network(data)
            loss = softmax_cross_entropy(output,label)
        loss.backward()
        param_update.step(data.shape[0])
        cumulative_loss += nd.sum(loss).asscalar()


# test_accuracy = accuracy(test_data,test_labels,network)
train_accuracy = accuracy(train_data,network)
print("Epoch %s. Loss: %s, Train_acc %s" %
      (e, cumulative_loss/num_instances, train_accuracy))
# Out:
# ---------------------------------------------------------------------------
# DeferredInitializationError               Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     705                         return self._call_cached_op(x, *args)
# --> 706                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
#     707                 except DeferredInitializationError:
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in <dictcomp>(.0)
#     705                         return self._call_cached_op(x, *args)
# --> 706                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
#     707                 except DeferredInitializationError:
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/parameter.py in data(self, ctx)
#     392         """
# --> 393         return self._check_and_get(self._data, ctx)
#     394
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/parameter.py in _check_and_get(self, arr_list, ctx)
#     182                 "You can also avoid deferred initialization by specifying in_units, " \
# --> 183                 "num_features, etc., for network layers."%(self.name))
#     184         raise RuntimeError(
#
# DeferredInitializationError: Parameter 'sequential0_dense5_weight' has not been initialized yet because initialization was deferred. Actual initialization happens during the first forward pass. Please pass one batch of data through the network before accessing Parameters. You can also avoid deferred initialization by specifying in_units, num_features, etc., for network layers.
#
# During handling of the above exception, another exception occurred:
#
# MXNetError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in _finish_deferred_init(self, hybrid, *args)
#     589         try:
# --> 590             self.infer_shape(*args)
#     591         except Exception as e:
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in infer_shape(self, *args)
#     658         """Infers shape of Parameters from inputs."""
# --> 659         self._infer_attrs('infer_shape', 'shape', *args)
#     660
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in _infer_attrs(self, infer_fn, attr, *args)
#     643         """Generic infer attributes."""
# --> 644         inputs, out = self._get_graph(*args)
#     645         args, _ = _flatten(args, "input")
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in _get_graph(self, *args)
#     556             with self.name_scope():
# --> 557                 out = self.hybrid_forward(symbol, *grouped_inputs, **params)  # pylint: disable=no-value-for-parameter
#     558             out, self._out_format = _flatten(out, "output")
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/nn/basic_layers.py in hybrid_forward(self, F, x, weight, bias)
#     208         if self.act is not None:
# --> 209             act = self.act(act)
#     210         return act
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     470         """Calls forward. Only accepts positional arguments."""
# --> 471         return self.forward(*args)
#     472
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     719         with self.name_scope():
# --> 720             return self.hybrid_forward(symbol, x, *args, **params)
#     721
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/nn/activations.py in hybrid_forward(self, F, x)
#      50     def hybrid_forward(self, F, x):
# ---> 51         return F.Activation(x, act_type=self._act_type, name='fwd')
#      52
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/symbol/register.py in Activation(data, act_type, name, attr, out, **kwargs)
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/_ctypes/symbol.py in _symbol_creator(handle, args, kwargs, keys, vals, name)
#     124         c_str_array([str(v) for v in vals]),
# --> 125         ctypes.byref(sym_handle)))
#     126
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/base.py in check_call(ret)
#     148     if ret != 0:
# --> 149         raise MXNetError(py_str(_LIB.MXGetLastError()))
#     150
#
# MXNetError: Invalid Input: 'softmax', valid values are: {'relu', 'sigmoid', 'softrelu', 'softsign', 'tanh'}, in operator Activation(name="", act_type="softmax")
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-20866617a8c0> in <module>
#      85         label = label.as_in_context(model_ctx)
#      86         with autograd.record():
# ---> 87             output = network(data)
#      88             loss = softmax_cross_entropy(output,label)
#      89         loss.backward()
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     469     def __call__(self, *args):
#     470         """Calls forward. Only accepts positional arguments."""
# --> 471         return self.forward(*args)
#     472
#     473     def forward(self, *args):
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/nn/basic_layers.py in forward(self, x)
#      51     def forward(self, x):
#      52         for block in self._children.values():
# ---> 53             x = block(x)
#      54         return x
#      55
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     469     def __call__(self, *args):
#     470         """Calls forward. Only accepts positional arguments."""
# --> 471         return self.forward(*args)
#     472
#     473     def forward(self, *args):
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     706                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
#     707                 except DeferredInitializationError:
# --> 708                     self._finish_deferred_init(self._active, x, *args)
#     709
#     710                 if self._active:
#
# ~/anaconda3/lib/python3.6/site-packages/mxnet/gluon/block.py in _finish_deferred_init(self, hybrid, *args)
#     592             error_msg = "Deferred initialization failed because shape"\
#     593                         " cannot be inferred \n {}".format(e)
# --> 594             raise ValueError(error_msg)
#     595
#     596         if hybrid:
#
# ValueError: Deferred initialization failed because shape cannot be inferred
#  Invalid Input: 'softmax', valid values are: {'relu', 'sigmoid', 'softrelu', 'softsign', 'tanh'}, in operator Activation(name="", act_type="softmax")
